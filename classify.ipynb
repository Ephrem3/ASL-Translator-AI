# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
import cv2  # Install opencv-python
import numpy as np

# %%
# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("keras_Model.h5", compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# %%
# CAMERA can be 0 or 1 based on default camera of your computer
camera = cv2.VideoCapture(0)

while True:
    # Grab the webcamera's image.
    ret, image = camera.read()

    # Resize the raw image into (224-height,224-width) pixels
    image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Show the image in a window
    cv2.imshow("Webcam Image", image)

    # Make the image a numpy array and reshape it to the models input shape.
    image = np.asarray(image, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize the image array
    image = (image / 127.5) - 1

    # Predicts the model
    prediction = model.predict(image)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Print prediction and confidence score
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", str(np.round(confidence_score * 100))[:-2], "%")

    key = cv2.waitKey(1)
    if key == ord('q'):
        break

camera.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 44ms/step
# Class: h
# Confidence Score: 40 %
# 1/1 [==============================] - 0s 48ms/step
# Class: g
# Confidence Score: 34 %
# 1/1 [==============================] - 0s 52ms/step
# Class: h
# Confidence Score: 42 %
# 1/1 [==============================] - 0s 43ms/step
# Class: g
# Confidence Score: 39 %
# 1/1 [==============================] - 0s 53ms/step
# Class: h
# Confidence Score: 38 %
# 1/1 [==============================] - 0s 53ms/step
# Class: h
# Confidence Score: 46 %
# 1/1 [==============================] - 0s 53ms/step
# Class: g
# Confidence Score: 37 %
# 1/1 [==============================] - 0s 56ms/step
# Class: h
# Confidence Score: 46 %
# 1/1 [==============================] - 0s 41ms/step
# Class: g
# Confidence Score: 39 %
# 1/1 [==============================] - 0s 181ms/step
# Class: h
# Confidence Score: 52 %
# 1/1 [==============================] - 0s 215ms/step
# Class: g
# Confidence Score: 40 %
# 1/1 [==============================] - 0s 95ms/step
# Class: h
# Confidence Score: 52 %
# 1/1 [==============================] - 0s 60ms/step
# Class: h
# Confidence Score: 51 %
# 1/1 [==============================] - 0s 70ms/step
# Class: h
# Confidence Score: 41 %
# 1/1 [==============================] - 0s 71ms/step
# Class: h
# Confidence Score: 45 %
# 1/1 [==============================] - 0s 49ms/step
# Class: h
# Confidence Score: 43 %
# 1/1 [==============================] - 0s 55ms/step
# Class: g
# Confidence Score: 46 %
# 1/1 [==============================] - 0s 55ms/step
# Class: g
# Confidence Score: 61 %
# 1/1 [==============================] - 0s 52ms/step
# Class: g
# Confidence Score: 62 %
# 1/1 [==============================] - 0s 69ms/step
# Class: g
# Confidence Score: 57 %
# 1/1 [==============================] - 0s 60ms/step
# Class: g
# Confidence Score: 66 %
# 1/1 [==============================] - 0s 55ms/step
# Class: g
# Confidence Score: 64 %
# 1/1 [==============================] - 0s 50ms/step
# Class: g
# Confidence Score: 52 %
# 1/1 [==============================] - 0s 52ms/step
# Class: g
# Confidence Score: 55 %
# 1/1 [==============================] - 0s 57ms/step
# Class: g
# Confidence Score: 54 %
# 1/1 [==============================] - 0s 54ms/step
# Class: g
# Confidence Score: 49 %
# 1/1 [==============================] - 0s 68ms/step
# Class: g
# Confidence Score: 49 %
# 1/1 [==============================] - 0s 64ms/step
# Class: g
# Confidence Score: 49 %
# 1/1 [==============================] - 0s 54ms/step
# Class: g
# Confidence Score: 50 %
# 1/1 [==============================] - 0s 56ms/step
# Class: g
# Confidence Score: 56 %
# 1/1 [==============================] - 0s 60ms/step
# Class: g
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 58ms/step
# Class: g
# Confidence Score: 47 %
# 1/1 [==============================] - 0s 59ms/step
# Class: g
# Confidence Score: 41 %
# 1/1 [==============================] - 0s 62ms/step
# Class: g
# Confidence Score: 57 %
# 1/1 [==============================] - 0s 58ms/step
# Class: g
# Confidence Score: 63 %
# 1/1 [==============================] - 0s 59ms/step
# Class: g
# Confidence Score: 57 %
# 1/1 [==============================] - 0s 51ms/step
# Class: g
# Confidence Score: 59 %
# 1/1 [==============================] - 0s 56ms/step
# Class: g
# Confidence Score: 55 %
# 1/1 [==============================] - 0s 45ms/step
# Class: g
# Confidence Score: 65 %
# 1/1 [==============================] - 0s 54ms/step
# Class: g
# Confidence Score: 60 %
# 1/1 [==============================] - 0s 42ms/step
# Class: g
# Confidence Score: 39 %
# 1/1 [==============================] - 0s 44ms/step
# Class: g
# Confidence Score: 35 %
# 1/1 [==============================] - 0s 56ms/step
# Class: g
# Confidence Score: 44 %
# 1/1 [==============================] - 0s 72ms/step
# Class: g
# Confidence Score: 38 %
# 1/1 [==============================] - 0s 84ms/step
# Class: g
# Confidence Score: 40 %
# 1/1 [==============================] - 0s 54ms/step
# Class: h
# Confidence Score: 40 %
# 1/1 [==============================] - 0s 52ms/step
# Class: g
# Confidence Score: 39 %
# 1/1 [==============================] - 0s 62ms/step
# Class: h
# Confidence Score: 38 %
# 1/1 [==============================] - 0s 54ms/step
# Class: h
# Confidence Score: 40 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Rinzler\ASL-Translator-AI\classify.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Rinzler/ASL-Translator-AI/classify.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a> image = (image / 127.5) - 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Rinzler/ASL-Translator-AI/classify.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a> # Predicts the model
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Rinzler/ASL-Translator-AI/classify.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a> prediction = model.predict(image)
#      <a href='vscode-notebook-cell:/c%3A/Users/Rinzler/ASL-Translator-AI/classify.ipynb#W2sZmlsZQ%3D%3D?line=21'>22</a> index = np.argmax(prediction)
#      <a href='vscode-notebook-cell:/c%3A/Users/Rinzler/ASL-Translator-AI/classify.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a> class_name = class_names[index]
#
# File c:\Users\Rinzler\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Rinzler\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:2620, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2611     except ValueError:
#    2612         warnings.warn(
#    2613             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2614             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2617             stacklevel=2,
#    2618         )
# -> 2620 data_handler = data_adapter.get_data_handler(
#    2621     x=x,
#    2622     batch_size=batch_size,
#    2623     steps_per_epoch=steps,
#    2624     initial_epoch=0,
#    2625     epochs=1,
#    2626     max_queue_size=max_queue_size,
#    2627     workers=workers,
#    2628     use_multiprocessing=use_multiprocessing,
#    2629     model=self,
#    2630     steps_per_execution=self._steps_per_execution,
#    2631 )
#    2633 # Container that configures and calls `tf.keras.Callback`s.
#    2634 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\Rinzler\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\data_adapter.py:1688, in get_data_handler(*args, **kwargs)
#    1686         return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1687     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1688 return DataHandler(*args, **kwargs)
#
# File c:\Users\Rinzler\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\data_adapter.py:1292, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1289     self._steps_per_execution = steps_per_execution
#    1291 adapter_cls = select_data_adapter(x, y)
# -> 1292 self._adapter = adapter_cls(
#    1293     x,
#    1294     y,
#    1295     batch_size=batch_size,
#    1296     steps=steps_per_epoch,
#    1297     epochs=epochs - initial_epoch,
#    1298     sample_weights=sample_weight,
#    1299     shuffle=shuffle,
#    1300     max_queue_size=max_queue_size,
#    1301     workers=workers,
#    1302     use_multiprocessing=use_multiprocessing,
#    1303     distribution_strategy=tf.distribute.get_strategy(),
#    1304     model=model,
#    1305     pss_evaluation_shards=pss_evaluation_shards,
#    1306 )
#    1308 strategy = tf.distribute.get_strategy()
#    1310 self._current_step = 0
#
# File c:\Users\Rinzler\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\data_adapter.py:314, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     307     return indices
#     309 # We prefetch a single element. Computing large permutations can take
#     310 # quite a while so we don't want to wait for prefetching over an epoch
#     311 # boundary to trigger the next permutation. On the other hand, too many
#     312 # simultaneous shuffles can contend on a hardware level and degrade all
#     313 # performance.
# --> 314 indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     316 def slice_batch_indices(indices):
#     317     """Convert a Tensor of indices into a dataset of batched indices.
#     318
#     319     This step can be accomplished in several ways. The most natural is
#    (...)
#     331       A Dataset of batched indices.
#     332     """
#
# File c:\Users\Rinzler\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2280, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2276 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2277 # dataset_ops).
#    2278 # pylint: disable=g-import-not-at-top,protected-access
#    2279 from tensorflow.python.data.ops import map_op
# -> 2280 return map_op._map_v2(
#    2281     self,
#    2282     map_func,
#    2283     num_parallel_calls=num_parallel_calls,
#    2284     deterministic=deterministic,
#    2285     name=name)
#
# File c:\Users\Rinzler\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\map_op.py:37, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      34   if deterministic is not None and not debug_mode.DEBUG_MODE:
#      35     warnings.warn("The `deterministic` argument has no effect unless the "
#      36                   "`num_parallel_calls` argument is specified.")
# ---> 37   return _MapDataset(
#      38       input_dataset, map_func, preserve_cardinality=True, name=name)
#      39 else:
#      40   return _ParallelMapDataset(
#      41       input_dataset,
#      42       map_func,
#    (...)
#      45       preserve_cardinality=True,
#      46       name=name)
#
# File c:\Users\Rinzler\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\map_op.py:113, in _MapDataset.__init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     107 self._map_func = structured_function.StructuredFunctionWrapper(
#     108     map_func,
#     109     self._transformation_name(),
#     110     dataset=input_dataset,
#     111     use_legacy_function=use_legacy_function)
#     112 self._name = name
# --> 113 variant_tensor = gen_dataset_ops.map_dataset(
#     114     input_dataset._variant_tensor,  # pylint: disable=protected-access
#     115     self._map_func.function.captured_inputs,
#     116     f=self._map_func.function,
#     117     use_inter_op_parallelism=self._use_inter_op_parallelism,
#     118     preserve_cardinality=self._preserve_cardinality,
#     119     **self._common_args)
#     120 super().__init__(input_dataset, variant_tensor)
#
# File c:\Users\Rinzler\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3472, in map_dataset(input_dataset, other_arguments, f, output_types, output_shapes, use_inter_op_parallelism, preserve_cardinality, metadata, name)
#    3470 if tld.is_eager:
#    3471   try:
# -> 3472     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3473       _ctx, "MapDataset", name, input_dataset, other_arguments, "f", f,
#    3474       "output_types", output_types, "output_shapes", output_shapes,
#    3475       "use_inter_op_parallelism", use_inter_op_parallelism,
#    3476       "preserve_cardinality", preserve_cardinality, "metadata", metadata)
#    3477     return _result
#    3478   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
